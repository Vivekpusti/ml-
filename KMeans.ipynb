# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb26c0c4-8fe3-4b85-a24a-5e0e350604d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb26c0c4-8fe3-4b85-a24a-5e0e350604d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Iris.csv to Iris.csv

# %%
import io
 
df = pd.read_csv(io.BytesIO(uploaded['Iris.csv']))
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# %%
km=KMeans(n_clusters=3,max_iter=400,verbose=True,tol=0.2)
pred=km.fit_predict(df[['PetalLengthCm','PetalWidthCm']])
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'],c=df['Id'])
score=accuracy_score(df['Id'],pred)
score
# Out:
# Initialization complete
# Iteration 0, inertia 42.75
# Converged at iteration 0: center shift 0.21993495168887925 within tolerance 0.3670956444444442.
# Initialization complete
# Iteration 0, inertia 47.76
# Converged at iteration 0: center shift 0.3208401658859307 within tolerance 0.3670956444444442.
# Initialization complete
# Iteration 0, inertia 47.58000000000001
# Converged at iteration 0: center shift 0.33892942280560073 within tolerance 0.3670956444444442.
# Initialization complete
# Iteration 0, inertia 41.77999999999998
# Converged at iteration 0: center shift 0.16408656261259907 within tolerance 0.3670956444444442.
# Initialization complete
# Iteration 0, inertia 44.11
# Converged at iteration 0: center shift 0.1685241489971145 within tolerance 0.3670956444444442.
# Initialization complete
# Iteration 0, inertia 45.36
# Converged at iteration 0: center shift 0.27155683255259727 within tolerance 0.3670956444444442.
# Initialization complete
# ...

# %%
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'],c=pred)
